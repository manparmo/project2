# %%
from ucimlrepo import fetch_ucirepo

from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

import pandas as pd

# fetch dataset 
taiwanese_bankruptcy_prediction = fetch_ucirepo(id=572) 

# data (as pandas dataframes) 
X = taiwanese_bankruptcy_prediction.data.features  #Rest of the DataFrame with all the features minus the Binary feature to predict
y = taiwanese_bankruptcy_prediction.data.targets   #Binary Feature to predict in the DataFrame



import project2_pipeline as pipeline
pipeline.binary_model_generator(X,y,("KNN",KNeighborsClassifier(n_neighbors=9)))
pipeline.binary_model_generator(X,y,("Logistic Regression",LogisticRegression()))
pipeline.binary_model_generator(X,y,("Random Forest",RandomForestClassifier()))
pipeline.binary_model_generator(X,y,("Decision Tree",tree.DecisionTreeClassifier()))
# Out:
# ******** Starting to run Dataset with  Model: KNN
#
#
# *****Testing Dataset as Is
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# \Accuracy of the model: 0.9677
# Balanced accuracy of the model: 0.5000
# ROC-AUC of the model: 0.6362
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1650
#            1       0.00      0.00      0.00        55
#
#     accuracy                           0.97      1705
#    macro avg       0.48      0.50      0.49      1705
# weighted avg       0.94      0.97      0.95      1705
#
#
# Confusion Matrix:
# [[1650    0]
#  [  55    0]]
#
# y_test .info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1705 entries, 5171 to 355
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  1705 non-null   int64
# dtypes: int64(1)
# memory usage: 26.6 KB
#
# y_test  as_is valuecounts
# Bankrupt?
# 0            1650
# 1              55
# Name: count, dtype: int64
#
#
# ***** Testing DataSet Undersampling
#
# y_resampled.info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, 1776 to 2045
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  330 non-null    int64
# dtypes: int64(1)
# memory usage: 5.2 KB
#
# y_resampled.valuecounts:
# Bankrupt?
# 0            165
# 1            165
# Name: count, dtype: int64
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# \Accuracy of the model: 0.6018
# Balanced accuracy of the model: 0.6009
# ROC-AUC of the model: 0.6441
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.60      0.75      1650
#            1       0.05      0.60      0.09        55
#
#     accuracy                           0.60      1705
#    macro avg       0.51      0.60      0.42      1705
# weighted avg       0.95      0.60      0.72      1705
#
#
# Confusion Matrix:
# [[993 657]
#  [ 22  33]]
#
#
# *****Testing DataSet OverSampling
#
# y_resampled.info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9898 entries, 0 to 9897
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  9898 non-null   int64
# dtypes: int64(1)
# memory usage: 77.5 KB
#
# y_resampled.valuecounts:
# Bankrupt?
# 0            4949
# 1            4949
# Name: count, dtype: int64
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# \Accuracy of the model: 0.8727
# Balanced accuracy of the model: 0.5652
# ROC-AUC of the model: 0.6315
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93      1650
#            1       0.07      0.24      0.11        55
#
#     accuracy                           0.87      1705
#    macro avg       0.52      0.57      0.52      1705
# weighted avg       0.94      0.87      0.90      1705
#
#
# Confusion Matrix:
# [[1475  175]
#  [  42   13]]
# Dataset with Highest Accuracy for modem KNN : ('as_is', 0.967741935483871)
#
# ******** Starting to run Dataset with  Model: Logistic Regression
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# *****Testing Dataset as Is
# \Accuracy of the model: 0.9566
# Balanced accuracy of the model: 0.4942
# ROC-AUC of the model: 0.5848
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1650
#            1       0.00      0.00      0.00        55
#
#     accuracy                           0.96      1705
#    macro avg       0.48      0.49      0.49      1705
# weighted avg       0.94      0.96      0.95      1705
#
#
# Confusion Matrix:
# [[1631   19]
#  [  55    0]]
#
# y_test .info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1705 entries, 5171 to 355
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  1705 non-null   int64
# dtypes: int64(1)
# memory usage: 26.6 KB
#
# y_test  as_is valuecounts
# Bankrupt?
# 0            1650
# 1              55
# Name: count, dtype: int64
#
#
# ***** Testing DataSet Undersampling
#
# y_resampled.info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, 1776 to 2045
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  330 non-null    int64
# dtypes: int64(1)
# memory usage: 5.2 KB
#
# y_resampled.valuecounts:
# Bankrupt?
# 0            165
# 1            165
# Name: count, dtype: int64
# \Accuracy of the model: 0.7601
# Balanced accuracy of the model: 0.5685
# ROC-AUC of the model: 0.6257
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.77      0.86      1650
#            1       0.05      0.36      0.09        55
#
#     accuracy                           0.76      1705
#    macro avg       0.51      0.57      0.48      1705
# weighted avg       0.94      0.76      0.84      1705
#
#
# Confusion Matrix:
# [[1276  374]
#  [  35   20]]
#
#
# *****Testing DataSet OverSampling
#
# y_resampled.info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9898 entries, 0 to 9897
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  9898 non-null   int64
# dtypes: int64(1)
# memory usage: 77.5 KB
#
# y_resampled.valuecounts:
# Bankrupt?
# 0            4949
# 1            4949
# Name: count, dtype: int64
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# \Accuracy of the model: 0.7425
# Balanced accuracy of the model: 0.5506
# ROC-AUC of the model: 0.6166
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.76      0.85      1650
#            1       0.05      0.35      0.08        55
#
#     accuracy                           0.74      1705
#    macro avg       0.51      0.55      0.46      1705
# weighted avg       0.94      0.74      0.83      1705
#
#
# Confusion Matrix:
# [[1247  403]
#  [  36   19]]
# Dataset with Highest Accuracy for modem Logistic Regression : ('as_is', 0.9565982404692082)
#
# ******** Starting to run Dataset with  Model: Random Forest
#
#
# *****Testing Dataset as Is
# \Accuracy of the model: 0.9689
# Balanced accuracy of the model: 0.5709
# ROC-AUC of the model: 0.9255
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1650
#            1       0.57      0.15      0.23        55
#
#     accuracy                           0.97      1705
#    macro avg       0.77      0.57      0.61      1705
# weighted avg       0.96      0.97      0.96      1705
#
#
# Confusion Matrix:
# [[1644    6]
#  [  47    8]]
#
# y_test .info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1705 entries, 5171 to 355
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  1705 non-null   int64
# dtypes: int64(1)
# memory usage: 26.6 KB
#
# y_test  as_is valuecounts
# Bankrupt?
# 0            1650
# 1              55
# Name: count, dtype: int64
#
#
# ***** Testing DataSet Undersampling
#
# y_resampled.info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, 1776 to 2045
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  330 non-null    int64
# dtypes: int64(1)
# memory usage: 5.2 KB
#
# y_resampled.valuecounts:
# Bankrupt?
# 0            165
# 1            165
# Name: count, dtype: int64
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# \Accuracy of the model: 0.8686
# Balanced accuracy of the model: 0.8442
# ROC-AUC of the model: 0.9329
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.93      1650
#            1       0.17      0.82      0.29        55
#
#     accuracy                           0.87      1705
#    macro avg       0.58      0.84      0.61      1705
# weighted avg       0.97      0.87      0.91      1705
#
#
# Confusion Matrix:
# [[1436  214]
#  [  10   45]]
#
#
# *****Testing DataSet OverSampling
#
# y_resampled.info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9898 entries, 0 to 9897
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  9898 non-null   int64
# dtypes: int64(1)
# memory usage: 77.5 KB
#
# y_resampled.valuecounts:
# Bankrupt?
# 0            4949
# 1            4949
# Name: count, dtype: int64
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# \Accuracy of the model: 0.9683
# Balanced accuracy of the model: 0.6409
# ROC-AUC of the model: 0.9279
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1650
#            1       0.52      0.29      0.37        55
#
#     accuracy                           0.97      1705
#    macro avg       0.75      0.64      0.68      1705
# weighted avg       0.96      0.97      0.96      1705
#
#
# Confusion Matrix:
# [[1635   15]
#  [  39   16]]
# Dataset with Highest Accuracy for modem Random Forest : ('as_is', 0.9689149560117302)
#
# ******** Starting to run Dataset with  Model: Decision Tree
#
#
# *****Testing Dataset as Is
# \Accuracy of the model: 0.9584
# Balanced accuracy of the model: 0.6533
# ROC-AUC of the model: 0.6533
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1650
#            1       0.35      0.33      0.34        55
#
#     accuracy                           0.96      1705
#    macro avg       0.66      0.65      0.66      1705
# weighted avg       0.96      0.96      0.96      1705
#
#
# Confusion Matrix:
# [[1616   34]
#  [  37   18]]
#
# y_test .info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1705 entries, 5171 to 355
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  1705 non-null   int64
# dtypes: int64(1)
# memory usage: 26.6 KB
#
# y_test  as_is valuecounts
# Bankrupt?
# 0            1650
# 1              55
# Name: count, dtype: int64
#
#
# ***** Testing DataSet Undersampling
#
# y_resampled.info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, 1776 to 2045
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  330 non-null    int64
# dtypes: int64(1)
# memory usage: 5.2 KB
#
# y_resampled.valuecounts:
# Bankrupt?
# 0            165
# 1            165
# Name: count, dtype: int64
# \Accuracy of the model: 0.8194
# Balanced accuracy of the model: 0.7748
# ROC-AUC of the model: 0.7748
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.90      1650
#            1       0.12      0.73      0.21        55
#
#     accuracy                           0.82      1705
#    macro avg       0.55      0.77      0.55      1705
# weighted avg       0.96      0.82      0.88      1705
#
#
# Confusion Matrix:
# [[1357  293]
#  [  15   40]]
#
#
# *****Testing DataSet OverSampling
#
# y_resampled.info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9898 entries, 0 to 9897
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bankrupt?  9898 non-null   int64
# dtypes: int64(1)
# memory usage: 77.5 KB
#
# y_resampled.valuecounts:
# Bankrupt?
# 0            4949
# 1            4949
# Name: count, dtype: int64
# \Accuracy of the model: 0.9548
# Balanced accuracy of the model: 0.6515
# ROC-AUC of the model: 0.6515
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1650
#            1       0.31      0.33      0.32        55
#
#     accuracy                           0.95      1705
#    macro avg       0.64      0.65      0.65      1705
# weighted avg       0.96      0.95      0.96      1705
#
#
# Confusion Matrix:
# [[1610   40]
#  [  37   18]]
# Dataset with Highest Accuracy for modem Decision Tree : ('as_is', 0.9583577712609971)
