# %%
from ucimlrepo import fetch_ucirepo

from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier



import pandas as pd
# fetch dataset 
#taiwanese_bankruptcy_prediction = fetch_ucirepo(id=572) 

# data (as pandas dataframes) 
#X = taiwanese_bankruptcy_prediction.data.features  #Rest of the DataFrame with all the features minus the Binary feature to predict
#y = taiwanese_bankruptcy_prediction.data.targets   #Binary Feature to predict in the DataFrame

df = pd.read_csv("Filtered_BankruptcyData.csv")
df.dropna()
df.info()
X = df.drop(columns=['Bankrupt?'])  # Drop the target column to keep only features
y = df['Bankrupt?']  # Target column

import project2_pipeline as pipeline
pipeline.binary_model_generator(X,y,("KNN",KNeighborsClassifier(n_neighbors=5)))
pipeline.binary_model_generator(X,y,("Logistic Regression",LogisticRegression()))
pipeline.binary_model_generator(X,y,("Random Forest",RandomForestClassifier()))
pipeline.binary_model_generator(X,y,("Decision Tree",tree.DecisionTreeClassifier()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Net Income to Stockholder's Equity                  6819 non-null   float64
#  1   Debt ratio %                                        6819 non-null   float64
#  2   Current Liability to Assets                         6819 non-null   float64
#  3   Borrowing dependency                                6819 non-null   float64
#  4   Retained Earnings to Total Assets                   6819 non-null   float64
#  5   Total Asset Turnover                                6819 non-null   float64
#  6   Operating Gross Margin                              6819 non-null   float64
#  7   Net Income to Total Assets                          6819 non-null   float64
# ...
